# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib  # for reading MR images
import tensorflow as tf
import keras as k
from tensorflow.keras import layers, regularizers
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
from keras.utils.vis_utils import plot_model
from collections import Counter
from sklearn.metrics import fbeta_score
from sklearn.metrics import jaccard_score
from skimage.metrics import peak_signal_noise_ratio as psnr
import pandas as pd
import seaborn as sns
tf.keras.backend.clear_session() # clearing any previous tensorflow sessions
# Out:
# 2023-09-13 20:25:20.361220: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-13 20:25:22.264266: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-09-13 20:25:26.452004: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.7/lib64:/opt/Python/Python-3.10.1/lib:/opt/ucl/lib:/usr/X11R6/lib
# 2023-09-13 20:25:26.452921: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.7/lib64:/opt/Python/Python-3.10.1/lib:/opt/ucl/lib:/usr/X11R6/lib
# 2023-09-13 20:25:26.452962: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
#Loading Dataset
t = time.process_time()

# Base directory path where the patient data is stored
base_directory_path = '/cluster/project2/UCSF_PDGM_dataset/UCSF-PDGM-v3/'

# Patient directories are named 'UCSF-PDGM-XXXX_nifti', where XXXX is the patient ID
all_patient_ids = [f"UCSF-PDGM-{str(i).zfill(4)}" for i in range(4, 542)]  # This will generate IDs from 0001 to 0541

# Excluded patients list because of FileNotFoundError, IndexError, ImageFileError
exclude_unavailbale_patients = {'UCSF-PDGM-0006', 'UCSF-PDGM-0028', 'UCSF-PDGM-0051', 'UCSF-PDGM-0052', 'UCSF-PDGM-0054', 'UCSF-PDGM-0060', 
                                'UCSF-PDGM-0062', 'UCSF-PDGM-0081', 'UCSF-PDGM-0098', 'UCSF-PDGM-0100', 'UCSF-PDGM-0108', 'UCSF-PDGM-0110',
                                'UCSF-PDGM-0117', 'UCSF-PDGM-0120', 'UCSF-PDGM-0125', 'UCSF-PDGM-0138', 'UCSF-PDGM-0171', 'UCSF-PDGM-0175',
                                'UCSF-PDGM-0177', 'UCSF-PDGM-0181', 'UCSF-PDGM-0192', 'UCSF-PDGM-0194', 'UCSF-PDGM-0199', 'UCSF-PDGM-0203',
                                'UCSF-PDGM-0206', 'UCSF-PDGM-0211', 'UCSF-PDGM-0216', 'UCSF-PDGM-0217', 'UCSF-PDGM-0218', 'UCSF-PDGM-0219',
                                'UCSF-PDGM-0220', 'UCSF-PDGM-0221', 'UCSF-PDGM-0222', 'UCSF-PDGM-0224', 'UCSF-PDGM-0226', 'UCSF-PDGM-0230',
                                'UCSF-PDGM-0231', 'UCSF-PDGM-0232', 'UCSF-PDGM-0233', 'UCSF-PDGM-0234', 'UCSF-PDGM-0235', 'UCSF-PDGM-0236',
                                'UCSF-PDGM-0237', 'UCSF-PDGM-0238', 'UCSF-PDGM-0239', 'UCSF-PDGM-0240', 'UCSF-PDGM-0241', 'UCSF-PDGM-0242',
                                'UCSF-PDGM-0244', 'UCSF-PDGM-0245', 'UCSF-PDGM-0246', 'UCSF-PDGM-0247', 'UCSF-PDGM-0248', 'UCSF-PDGM-0249',
                                'UCSF-PDGM-0250', 'UCSF-PDGM-0251', 'UCSF-PDGM-0252', 'UCSF-PDGM-0254', 'UCSF-PDGM-0255', 'UCSF-PDGM-0256',
                                'UCSF-PDGM-0257', 'UCSF-PDGM-0258', 'UCSF-PDGM-0259', 'UCSF-PDGM-0260', 'UCSF-PDGM-0261', 'UCSF-PDGM-0262',
                                'UCSF-PDGM-0263', 'UCSF-PDGM-0264', 'UCSF-PDGM-0265', 'UCSF-PDGM-0266', 'UCSF-PDGM-0267', 'UCSF-PDGM-0268',
                                'UCSF-PDGM-0269', 'UCSF-PDGM-0271', 'UCSF-PDGM-0272', 'UCSF-PDGM-0274', 'UCSF-PDGM-0277', 'UCSF-PDGM-0278',
                                'UCSF-PDGM-0281', 'UCSF-PDGM-0282', 'UCSF-PDGM-0286', 'UCSF-PDGM-0289', 'UCSF-PDGM-0292', 'UCSF-PDGM-0293',
                                'UCSF-PDGM-0294', 'UCSF-PDGM-0298', 'UCSF-PDGM-0299', 'UCSF-PDGM-0300', 'UCSF-PDGM-0301', 'UCSF-PDGM-0302',
                                'UCSF-PDGM-0305', 'UCSF-PDGM-0307', 'UCSF-PDGM-0308', 'UCSF-PDGM-0315', 'UCSF-PDGM-0322', 'UCSF-PDGM-0326',
                                'UCSF-PDGM-0327', 'UCSF-PDGM-0331', 'UCSF-PDGM-0345', 'UCSF-PDGM-0349', 'UCSF-PDGM-0351', 'UCSF-PDGM-0352',
                                'UCSF-PDGM-0357', 'UCSF-PDGM-0365', 'UCSF-PDGM-0371', 'UCSF-PDGM-0374', 'UCSF-PDGM-0378', 'UCSF-PDGM-0383',
                                'UCSF-PDGM-0388', 'UCSF-PDGM-0395', 'UCSF-PDGM-0408', 'UCSF-PDGM-0436', 'UCSF-PDGM-0437', 'UCSF-PDGM-0438',
                                'UCSF-PDGM-0439', 'UCSF-PDGM-0440', 'UCSF-PDGM-0441', 'UCSF-PDGM-0442', 'UCSF-PDGM-0444', 'UCSF-PDGM-0445', 
                                'UCSF-PDGM-0446', 'UCSF-PDGM-0448', 'UCSF-PDGM-0449', 'UCSF-PDGM-0456', 'UCSF-PDGM-0465', 'UCSF-PDGM-0466', 
                                'UCSF-PDGM-0468', 'UCSF-PDGM-0469', 'UCSF-PDGM-0473', 'UCSF-PDGM-0474', 'UCSF-PDGM-0475', 'UCSF-PDGM-0476', 
                                'UCSF-PDGM-0477', 'UCSF-PDGM-0478', 'UCSF-PDGM-0482', 'UCSF-PDGM-0483', 'UCSF-PDGM-0485', 'UCSF-PDGM-0486',
                                'UCSF-PDGM-0489', 'UCSF-PDGM-0490', 'UCSF-PDGM-0500', 'UCSF-PDGM-0501', 'UCSF-PDGM-0530', 'UCSF-PDGM-0534', 
                                'UCSF-PDGM-0535', 'UCSF-PDGM-0537', 'UCSF-PDGM-0540', 'UCSF-PDGM-0541'}

all_data_merged = []
all_data_tumour_mask = []
num_of_images = 0
num_of_patients = 0

print("Loading images: ", end="")
for patient_id in all_patient_ids:

    if patient_id in exclude_unavailbale_patients:
        continue
    
    # Construct file paths for the current patient
    t1_bias_path = os.path.join(base_directory_path, f"{patient_id}_nifti", f"{patient_id}_T1_bias.nii.gz") #modality 1
    t2_bias_path = os.path.join(base_directory_path, f"{patient_id}_nifti", f"{patient_id}_T2_bias.nii.gz") #modality 2
    asl_path = os.path.join(base_directory_path, f"{patient_id}_nifti", f"{patient_id}_ASL.nii.gz") #modality 3
    flair_bias_path = os.path.join(base_directory_path, f"{patient_id}_nifti", f"{patient_id}_FLAIR_bias.nii.gz") #modality 4
    tumour_seg_path = os.path.join(base_directory_path, f"{patient_id}_nifti", f"{patient_id}_tumor_segmentation.nii.gz")
    
    # Load the images
    image_t1_bias = nib.load(t1_bias_path)
    image_t2_bias = nib.load(t2_bias_path)
    image_flair_bias = nib.load(flair_bias_path)
    image_asl = nib.load(asl_path)
    image_tumour_seg = nib.load(tumour_seg_path)
    
    # Get the image data as numpy arrays
    data_t1_bias = image_t1_bias.get_fdata()
    data_t2_bias = image_t2_bias.get_fdata()
    data_flair_bias = image_flair_bias.get_fdata()
    data_asl = image_asl.get_fdata()
    data_tumour_seg = image_tumour_seg.get_fdata()
    
    unique_labels = np.unique(data_tumour_seg)
    data_tumour_mask = np.where(data_tumour_seg == unique_labels[3], 1, 0)  # The label of interest is at index 3

    slice_start = 70  # Starting slice number
    slice_end = 85    # End slice number

    # Append the data to the lists
    for i in range(slice_start, slice_end):
        all_data_merged.append(data_t1_bias[:, :, i])
        all_data_tumour_mask.append(data_tumour_mask[:, :, i])
        all_data_merged.append(data_t2_bias[:, :, i])
        all_data_tumour_mask.append(data_tumour_mask[:, :, i])
        all_data_merged.append(data_flair_bias[:, :, i])
        all_data_tumour_mask.append(data_tumour_mask[:, :, i])
        all_data_merged.append(data_asl[:, :, i])
        all_data_tumour_mask.append(data_tumour_mask[:, :, i])
        num_of_images = num_of_images + 4
    #print(".", end="")
    
    print("Number of images loaded:", num_of_images, "of patient:", patient_id)
    num_of_patients = num_of_patients + 1

print(" => Images Loaded.")
elapsed_time = time.process_time() - t
print("Total time taken to load",num_of_images, "images of", num_of_patients,"patients:",elapsed_time, "seconds or", elapsed_time//60, "minutes.")
print("Total number of slices considered:", slice_end-slice_start)
# Convert lists to numpy arrays for further processing if needed
all_data_merged = np.asarray(all_data_merged)
all_data_tumour_mask = np.asarray(all_data_tumour_mask)
# Out:
# Loading images: Number of images loaded: 60 of patient: UCSF-PDGM-0004
# Number of images loaded: 120 of patient: UCSF-PDGM-0005
# Number of images loaded: 180 of patient: UCSF-PDGM-0007
# Number of images loaded: 240 of patient: UCSF-PDGM-0008
# Number of images loaded: 300 of patient: UCSF-PDGM-0009
# Number of images loaded: 360 of patient: UCSF-PDGM-0010
# Number of images loaded: 420 of patient: UCSF-PDGM-0011
# Number of images loaded: 480 of patient: UCSF-PDGM-0012
# Number of images loaded: 540 of patient: UCSF-PDGM-0013
# Number of images loaded: 600 of patient: UCSF-PDGM-0014
# Number of images loaded: 660 of patient: UCSF-PDGM-0015
# Number of images loaded: 720 of patient: UCSF-PDGM-0016
# Number of images loaded: 780 of patient: UCSF-PDGM-0017
# Number of images loaded: 840 of patient: UCSF-PDGM-0018
# Number of images loaded: 900 of patient: UCSF-PDGM-0019
# Number of images loaded: 960 of patient: UCSF-PDGM-0020
# Number of images loaded: 1020 of patient: UCSF-PDGM-0021
# Number of images loaded: 1080 of patient: UCSF-PDGM-0022
# Number of images loaded: 1140 of patient: UCSF-PDGM-0023
# Number of images loaded: 1200 of patient: UCSF-PDGM-0024
# Number of images loaded: 1260 of patient: UCSF-PDGM-0025
# Number of images loaded: 1320 of patient: UCSF-PDGM-0026
# Number of images loaded: 1380 of patient: UCSF-PDGM-0027
# Number of images loaded: 1440 of patient: UCSF-PDGM-0029
# Number of images loaded: 1500 of patient: UCSF-PDGM-0030
# Number of images loaded: 1560 of patient: UCSF-PDGM-0031
# Number of images loaded: 1620 of patient: UCSF-PDGM-0032
# Number of images loaded: 1680 of patient: UCSF-PDGM-0033
# Number of images loaded: 1740 of patient: UCSF-PDGM-0034
# Number of images loaded: 1800 of patient: UCSF-PDGM-0035
# Number of images loaded: 1860 of patient: UCSF-PDGM-0036
# Number of images loaded: 1920 of patient: UCSF-PDGM-0037
# Number of images loaded: 1980 of patient: UCSF-PDGM-0038
# Number of images loaded: 2040 of patient: UCSF-PDGM-0039
# Number of images loaded: 2100 of patient: UCSF-PDGM-0040
# Number of images loaded: 2160 of patient: UCSF-PDGM-0041
# Number of images loaded: 2220 of patient: UCSF-PDGM-0042
# Number of images loaded: 2280 of patient: UCSF-PDGM-0043
# Number of images loaded: 2340 of patient: UCSF-PDGM-0044
# Number of images loaded: 2400 of patient: UCSF-PDGM-0045
# Number of images loaded: 2460 of patient: UCSF-PDGM-0046
# Number of images loaded: 2520 of patient: UCSF-PDGM-0047
# Number of images loaded: 2580 of patient: UCSF-PDGM-0048
# Number of images loaded: 2640 of patient: UCSF-PDGM-0049
# Number of images loaded: 2700 of patient: UCSF-PDGM-0050
# Number of images loaded: 2760 of patient: UCSF-PDGM-0053
# Number of images loaded: 2820 of patient: UCSF-PDGM-0055
# Number of images loaded: 2880 of patient: UCSF-PDGM-0056
# Number of images loaded: 2940 of patient: UCSF-PDGM-0057
# Number of images loaded: 3000 of patient: UCSF-PDGM-0058
# Number of images loaded: 3060 of patient: UCSF-PDGM-0059
# Number of images loaded: 3120 of patient: UCSF-PDGM-0061
# Number of images loaded: 3180 of patient: UCSF-PDGM-0063
# Number of images loaded: 3240 of patient: UCSF-PDGM-0064
# Number of images loaded: 3300 of patient: UCSF-PDGM-0065
# Number of images loaded: 3360 of patient: UCSF-PDGM-0066
# Number of images loaded: 3420 of patient: UCSF-PDGM-0067
# Number of images loaded: 3480 of patient: UCSF-PDGM-0068
# Number of images loaded: 3540 of patient: UCSF-PDGM-0069
# Number of images loaded: 3600 of patient: UCSF-PDGM-0070
# Number of images loaded: 3660 of patient: UCSF-PDGM-0071
# Number of images loaded: 3720 of patient: UCSF-PDGM-0072
# Number of images loaded: 3780 of patient: UCSF-PDGM-0073
# Number of images loaded: 3840 of patient: UCSF-PDGM-0074
# Number of images loaded: 3900 of patient: UCSF-PDGM-0075
# Number of images loaded: 3960 of patient: UCSF-PDGM-0076
# Number of images loaded: 4020 of patient: UCSF-PDGM-0077
# Number of images loaded: 4080 of patient: UCSF-PDGM-0078
# Number of images loaded: 4140 of patient: UCSF-PDGM-0079
# Number of images loaded: 4200 of patient: UCSF-PDGM-0080
# Number of images loaded: 4260 of patient: UCSF-PDGM-0082
# Number of images loaded: 4320 of patient: UCSF-PDGM-0083
# Number of images loaded: 4380 of patient: UCSF-PDGM-0084
# Number of images loaded: 4440 of patient: UCSF-PDGM-0085
# Number of images loaded: 4500 of patient: UCSF-PDGM-0086
# Number of images loaded: 4560 of patient: UCSF-PDGM-0087
# Number of images loaded: 4620 of patient: UCSF-PDGM-0088
# Number of images loaded: 4680 of patient: UCSF-PDGM-0089
# Number of images loaded: 4740 of patient: UCSF-PDGM-0090
# Number of images loaded: 4800 of patient: UCSF-PDGM-0091
# Number of images loaded: 4860 of patient: UCSF-PDGM-0092
# Number of images loaded: 4920 of patient: UCSF-PDGM-0093
# Number of images loaded: 4980 of patient: UCSF-PDGM-0094
# Number of images loaded: 5040 of patient: UCSF-PDGM-0095
# Number of images loaded: 5100 of patient: UCSF-PDGM-0096
# Number of images loaded: 5160 of patient: UCSF-PDGM-0097
# Number of images loaded: 5220 of patient: UCSF-PDGM-0099
# Number of images loaded: 5280 of patient: UCSF-PDGM-0101
# Number of images loaded: 5340 of patient: UCSF-PDGM-0102
# Number of images loaded: 5400 of patient: UCSF-PDGM-0103
# Number of images loaded: 5460 of patient: UCSF-PDGM-0104
# Number of images loaded: 5520 of patient: UCSF-PDGM-0105
# Number of images loaded: 5580 of patient: UCSF-PDGM-0106
# Number of images loaded: 5640 of patient: UCSF-PDGM-0107
# Number of images loaded: 5700 of patient: UCSF-PDGM-0109
# Number of images loaded: 5760 of patient: UCSF-PDGM-0111
# Number of images loaded: 5820 of patient: UCSF-PDGM-0112
# Number of images loaded: 5880 of patient: UCSF-PDGM-0113
# Number of images loaded: 5940 of patient: UCSF-PDGM-0114
# Number of images loaded: 6000 of patient: UCSF-PDGM-0115
# Number of images loaded: 6060 of patient: UCSF-PDGM-0116
# Number of images loaded: 6120 of patient: UCSF-PDGM-0118
# Number of images loaded: 6180 of patient: UCSF-PDGM-0119
# Number of images loaded: 6240 of patient: UCSF-PDGM-0121
# Number of images loaded: 6300 of patient: UCSF-PDGM-0122
# Number of images loaded: 6360 of patient: UCSF-PDGM-0123
# Number of images loaded: 6420 of patient: UCSF-PDGM-0124
# Number of images loaded: 6480 of patient: UCSF-PDGM-0126
# Number of images loaded: 6540 of patient: UCSF-PDGM-0127
# Number of images loaded: 6600 of patient: UCSF-PDGM-0128
# Number of images loaded: 6660 of patient: UCSF-PDGM-0129
# Number of images loaded: 6720 of patient: UCSF-PDGM-0130
# Number of images loaded: 6780 of patient: UCSF-PDGM-0131
# Number of images loaded: 6840 of patient: UCSF-PDGM-0132
# Number of images loaded: 6900 of patient: UCSF-PDGM-0133
# Number of images loaded: 6960 of patient: UCSF-PDGM-0134
# Number of images loaded: 7020 of patient: UCSF-PDGM-0135
# Number of images loaded: 7080 of patient: UCSF-PDGM-0136
# Number of images loaded: 7140 of patient: UCSF-PDGM-0137
# Number of images loaded: 7200 of patient: UCSF-PDGM-0139
# Number of images loaded: 7260 of patient: UCSF-PDGM-0140
# Number of images loaded: 7320 of patient: UCSF-PDGM-0141
# Number of images loaded: 7380 of patient: UCSF-PDGM-0142
# Number of images loaded: 7440 of patient: UCSF-PDGM-0143
# Number of images loaded: 7500 of patient: UCSF-PDGM-0144
# Number of images loaded: 7560 of patient: UCSF-PDGM-0145
# Number of images loaded: 7620 of patient: UCSF-PDGM-0146
# Number of images loaded: 7680 of patient: UCSF-PDGM-0147
# Number of images loaded: 7740 of patient: UCSF-PDGM-0148
# Number of images loaded: 7800 of patient: UCSF-PDGM-0149
# Number of images loaded: 7860 of patient: UCSF-PDGM-0150
# Number of images loaded: 7920 of patient: UCSF-PDGM-0151
# Number of images loaded: 7980 of patient: UCSF-PDGM-0152
# Number of images loaded: 8040 of patient: UCSF-PDGM-0153
# Number of images loaded: 8100 of patient: UCSF-PDGM-0154
# Number of images loaded: 8160 of patient: UCSF-PDGM-0155
# Number of images loaded: 8220 of patient: UCSF-PDGM-0156
# Number of images loaded: 8280 of patient: UCSF-PDGM-0157
# Number of images loaded: 8340 of patient: UCSF-PDGM-0158
# Number of images loaded: 8400 of patient: UCSF-PDGM-0159
# Number of images loaded: 8460 of patient: UCSF-PDGM-0160
# Number of images loaded: 8520 of patient: UCSF-PDGM-0161
# Number of images loaded: 8580 of patient: UCSF-PDGM-0162
# Number of images loaded: 8640 of patient: UCSF-PDGM-0163
# Number of images loaded: 8700 of patient: UCSF-PDGM-0164
# Number of images loaded: 8760 of patient: UCSF-PDGM-0165
# Number of images loaded: 8820 of patient: UCSF-PDGM-0166
# Number of images loaded: 8880 of patient: UCSF-PDGM-0167
# Number of images loaded: 8940 of patient: UCSF-PDGM-0168
# Number of images loaded: 9000 of patient: UCSF-PDGM-0169
# Number of images loaded: 9060 of patient: UCSF-PDGM-0170
# Number of images loaded: 9120 of patient: UCSF-PDGM-0172
# Number of images loaded: 9180 of patient: UCSF-PDGM-0173
# Number of images loaded: 9240 of patient: UCSF-PDGM-0174
# Number of images loaded: 9300 of patient: UCSF-PDGM-0176
# Number of images loaded: 9360 of patient: UCSF-PDGM-0178
# Number of images loaded: 9420 of patient: UCSF-PDGM-0179
# Number of images loaded: 9480 of patient: UCSF-PDGM-0180
# Number of images loaded: 9540 of patient: UCSF-PDGM-0182
# Number of images loaded: 9600 of patient: UCSF-PDGM-0183
# Number of images loaded: 9660 of patient: UCSF-PDGM-0184
# Number of images loaded: 9720 of patient: UCSF-PDGM-0185
# Number of images loaded: 9780 of patient: UCSF-PDGM-0186
# Number of images loaded: 9840 of patient: UCSF-PDGM-0187
# Number of images loaded: 9900 of patient: UCSF-PDGM-0188
# Number of images loaded: 9960 of patient: UCSF-PDGM-0189
# Number of images loaded: 10020 of patient: UCSF-PDGM-0190
# Number of images loaded: 10080 of patient: UCSF-PDGM-0191
# Number of images loaded: 10140 of patient: UCSF-PDGM-0193
# Number of images loaded: 10200 of patient: UCSF-PDGM-0195
# Number of images loaded: 10260 of patient: UCSF-PDGM-0196
# Number of images loaded: 10320 of patient: UCSF-PDGM-0197
# Number of images loaded: 10380 of patient: UCSF-PDGM-0198
# Number of images loaded: 10440 of patient: UCSF-PDGM-0200
# Number of images loaded: 10500 of patient: UCSF-PDGM-0201
# Number of images loaded: 10560 of patient: UCSF-PDGM-0202
# Number of images loaded: 10620 of patient: UCSF-PDGM-0204
# Number of images loaded: 10680 of patient: UCSF-PDGM-0205
# Number of images loaded: 10740 of patient: UCSF-PDGM-0207
# Number of images loaded: 10800 of patient: UCSF-PDGM-0208
# Number of images loaded: 10860 of patient: UCSF-PDGM-0209
# Number of images loaded: 10920 of patient: UCSF-PDGM-0210
# Number of images loaded: 10980 of patient: UCSF-PDGM-0212
# Number of images loaded: 11040 of patient: UCSF-PDGM-0213
# Number of images loaded: 11100 of patient: UCSF-PDGM-0214
# Number of images loaded: 11160 of patient: UCSF-PDGM-0215
# Number of images loaded: 11220 of patient: UCSF-PDGM-0223
# Number of images loaded: 11280 of patient: UCSF-PDGM-0225
# Number of images loaded: 11340 of patient: UCSF-PDGM-0227
# Number of images loaded: 11400 of patient: UCSF-PDGM-0228
# Number of images loaded: 11460 of patient: UCSF-PDGM-0229
# Number of images loaded: 11520 of patient: UCSF-PDGM-0243
# Number of images loaded: 11580 of patient: UCSF-PDGM-0253
# Number of images loaded: 11640 of patient: UCSF-PDGM-0270
# Number of images loaded: 11700 of patient: UCSF-PDGM-0273
# Number of images loaded: 11760 of patient: UCSF-PDGM-0275
# Number of images loaded: 11820 of patient: UCSF-PDGM-0276
# Number of images loaded: 11880 of patient: UCSF-PDGM-0279
# Number of images loaded: 11940 of patient: UCSF-PDGM-0280
# Number of images loaded: 12000 of patient: UCSF-PDGM-0283
# Number of images loaded: 12060 of patient: UCSF-PDGM-0284
# Number of images loaded: 12120 of patient: UCSF-PDGM-0285
# Number of images loaded: 12180 of patient: UCSF-PDGM-0287
# Number of images loaded: 12240 of patient: UCSF-PDGM-0288
# Number of images loaded: 12300 of patient: UCSF-PDGM-0290
# Number of images loaded: 12360 of patient: UCSF-PDGM-0291
# Number of images loaded: 12420 of patient: UCSF-PDGM-0295
# Number of images loaded: 12480 of patient: UCSF-PDGM-0296
# Number of images loaded: 12540 of patient: UCSF-PDGM-0297
# Number of images loaded: 12600 of patient: UCSF-PDGM-0303
# Number of images loaded: 12660 of patient: UCSF-PDGM-0304
# Number of images loaded: 12720 of patient: UCSF-PDGM-0306
# Number of images loaded: 12780 of patient: UCSF-PDGM-0309
# Number of images loaded: 12840 of patient: UCSF-PDGM-0310
# Number of images loaded: 12900 of patient: UCSF-PDGM-0311
# Number of images loaded: 12960 of patient: UCSF-PDGM-0312
# Number of images loaded: 13020 of patient: UCSF-PDGM-0313
# Number of images loaded: 13080 of patient: UCSF-PDGM-0314
# Number of images loaded: 13140 of patient: UCSF-PDGM-0316
# Number of images loaded: 13200 of patient: UCSF-PDGM-0317
# Number of images loaded: 13260 of patient: UCSF-PDGM-0318
# Number of images loaded: 13320 of patient: UCSF-PDGM-0319
# Number of images loaded: 13380 of patient: UCSF-PDGM-0320
# Number of images loaded: 13440 of patient: UCSF-PDGM-0321
# Number of images loaded: 13500 of patient: UCSF-PDGM-0323
# Number of images loaded: 13560 of patient: UCSF-PDGM-0324
# Number of images loaded: 13620 of patient: UCSF-PDGM-0325
# Number of images loaded: 13680 of patient: UCSF-PDGM-0328
# Number of images loaded: 13740 of patient: UCSF-PDGM-0329
# Number of images loaded: 13800 of patient: UCSF-PDGM-0330
# Number of images loaded: 13860 of patient: UCSF-PDGM-0332
# Number of images loaded: 13920 of patient: UCSF-PDGM-0333
# Number of images loaded: 13980 of patient: UCSF-PDGM-0334
# Number of images loaded: 14040 of patient: UCSF-PDGM-0335
# Number of images loaded: 14100 of patient: UCSF-PDGM-0336
# Number of images loaded: 14160 of patient: UCSF-PDGM-0337
# Number of images loaded: 14220 of patient: UCSF-PDGM-0338
# Number of images loaded: 14280 of patient: UCSF-PDGM-0339
# Number of images loaded: 14340 of patient: UCSF-PDGM-0340
# Number of images loaded: 14400 of patient: UCSF-PDGM-0341
# Number of images loaded: 14460 of patient: UCSF-PDGM-0342
# Number of images loaded: 14520 of patient: UCSF-PDGM-0343
# Number of images loaded: 14580 of patient: UCSF-PDGM-0344
# Number of images loaded: 14640 of patient: UCSF-PDGM-0346
# Number of images loaded: 14700 of patient: UCSF-PDGM-0347
# Number of images loaded: 14760 of patient: UCSF-PDGM-0348
# Number of images loaded: 14820 of patient: UCSF-PDGM-0350
# Number of images loaded: 14880 of patient: UCSF-PDGM-0353
# Number of images loaded: 14940 of patient: UCSF-PDGM-0354
# Number of images loaded: 15000 of patient: UCSF-PDGM-0355
# Number of images loaded: 15060 of patient: UCSF-PDGM-0356
# Number of images loaded: 15120 of patient: UCSF-PDGM-0358
# Number of images loaded: 15180 of patient: UCSF-PDGM-0359
# Number of images loaded: 15240 of patient: UCSF-PDGM-0360
# Number of images loaded: 15300 of patient: UCSF-PDGM-0361
# Number of images loaded: 15360 of patient: UCSF-PDGM-0362
# Number of images loaded: 15420 of patient: UCSF-PDGM-0363
# Number of images loaded: 15480 of patient: UCSF-PDGM-0364
# Number of images loaded: 15540 of patient: UCSF-PDGM-0366
# Number of images loaded: 15600 of patient: UCSF-PDGM-0367
# Number of images loaded: 15660 of patient: UCSF-PDGM-0368
# Number of images loaded: 15720 of patient: UCSF-PDGM-0369
# Number of images loaded: 15780 of patient: UCSF-PDGM-0370
# Number of images loaded: 15840 of patient: UCSF-PDGM-0372
# Number of images loaded: 15900 of patient: UCSF-PDGM-0373
# Number of images loaded: 15960 of patient: UCSF-PDGM-0375
# Number of images loaded: 16020 of patient: UCSF-PDGM-0376
# Number of images loaded: 16080 of patient: UCSF-PDGM-0377
# Number of images loaded: 16140 of patient: UCSF-PDGM-0379
# Number of images loaded: 16200 of patient: UCSF-PDGM-0380
# Number of images loaded: 16260 of patient: UCSF-PDGM-0381
# Number of images loaded: 16320 of patient: UCSF-PDGM-0382
# Number of images loaded: 16380 of patient: UCSF-PDGM-0384
# Number of images loaded: 16440 of patient: UCSF-PDGM-0385
# Number of images loaded: 16500 of patient: UCSF-PDGM-0386
# Number of images loaded: 16560 of patient: UCSF-PDGM-0387
# Number of images loaded: 16620 of patient: UCSF-PDGM-0389
# Number of images loaded: 16680 of patient: UCSF-PDGM-0390
# Number of images loaded: 16740 of patient: UCSF-PDGM-0391
# Number of images loaded: 16800 of patient: UCSF-PDGM-0392
# Number of images loaded: 16860 of patient: UCSF-PDGM-0393
# Number of images loaded: 16920 of patient: UCSF-PDGM-0394
# Number of images loaded: 16980 of patient: UCSF-PDGM-0396
# Number of images loaded: 17040 of patient: UCSF-PDGM-0397
# Number of images loaded: 17100 of patient: UCSF-PDGM-0398
# Number of images loaded: 17160 of patient: UCSF-PDGM-0399
# Number of images loaded: 17220 of patient: UCSF-PDGM-0400
# Number of images loaded: 17280 of patient: UCSF-PDGM-0401
# Number of images loaded: 17340 of patient: UCSF-PDGM-0402
# Number of images loaded: 17400 of patient: UCSF-PDGM-0403
# Number of images loaded: 17460 of patient: UCSF-PDGM-0404
# Number of images loaded: 17520 of patient: UCSF-PDGM-0405
# Number of images loaded: 17580 of patient: UCSF-PDGM-0406
# Number of images loaded: 17640 of patient: UCSF-PDGM-0407
# Number of images loaded: 17700 of patient: UCSF-PDGM-0409
# Number of images loaded: 17760 of patient: UCSF-PDGM-0410
# Number of images loaded: 17820 of patient: UCSF-PDGM-0411
# Number of images loaded: 17880 of patient: UCSF-PDGM-0412
# Number of images loaded: 17940 of patient: UCSF-PDGM-0413
# Number of images loaded: 18000 of patient: UCSF-PDGM-0414
# Number of images loaded: 18060 of patient: UCSF-PDGM-0415
# Number of images loaded: 18120 of patient: UCSF-PDGM-0416
# Number of images loaded: 18180 of patient: UCSF-PDGM-0417
# Number of images loaded: 18240 of patient: UCSF-PDGM-0418
# Number of images loaded: 18300 of patient: UCSF-PDGM-0419
# Number of images loaded: 18360 of patient: UCSF-PDGM-0420
# Number of images loaded: 18420 of patient: UCSF-PDGM-0421
# Number of images loaded: 18480 of patient: UCSF-PDGM-0422
# Number of images loaded: 18540 of patient: UCSF-PDGM-0423
# Number of images loaded: 18600 of patient: UCSF-PDGM-0424
# Number of images loaded: 18660 of patient: UCSF-PDGM-0425
# Number of images loaded: 18720 of patient: UCSF-PDGM-0426
# Number of images loaded: 18780 of patient: UCSF-PDGM-0427
# Number of images loaded: 18840 of patient: UCSF-PDGM-0428
# Number of images loaded: 18900 of patient: UCSF-PDGM-0429
# Number of images loaded: 18960 of patient: UCSF-PDGM-0430
# Number of images loaded: 19020 of patient: UCSF-PDGM-0431
# Number of images loaded: 19080 of patient: UCSF-PDGM-0432
# Number of images loaded: 19140 of patient: UCSF-PDGM-0433
# Number of images loaded: 19200 of patient: UCSF-PDGM-0434
# Number of images loaded: 19260 of patient: UCSF-PDGM-0435
# Number of images loaded: 19320 of patient: UCSF-PDGM-0443
# Number of images loaded: 19380 of patient: UCSF-PDGM-0447
# Number of images loaded: 19440 of patient: UCSF-PDGM-0450
# Number of images loaded: 19500 of patient: UCSF-PDGM-0451
# Number of images loaded: 19560 of patient: UCSF-PDGM-0452
# Number of images loaded: 19620 of patient: UCSF-PDGM-0453
# Number of images loaded: 19680 of patient: UCSF-PDGM-0454
# Number of images loaded: 19740 of patient: UCSF-PDGM-0455
# Number of images loaded: 19800 of patient: UCSF-PDGM-0457
# Number of images loaded: 19860 of patient: UCSF-PDGM-0458
# Number of images loaded: 19920 of patient: UCSF-PDGM-0459
# Number of images loaded: 19980 of patient: UCSF-PDGM-0460
# Number of images loaded: 20040 of patient: UCSF-PDGM-0461
# Number of images loaded: 20100 of patient: UCSF-PDGM-0462
# Number of images loaded: 20160 of patient: UCSF-PDGM-0463
# Number of images loaded: 20220 of patient: UCSF-PDGM-0464
# Number of images loaded: 20280 of patient: UCSF-PDGM-0467
# Number of images loaded: 20340 of patient: UCSF-PDGM-0470
# Number of images loaded: 20400 of patient: UCSF-PDGM-0471
# Number of images loaded: 20460 of patient: UCSF-PDGM-0472
# Number of images loaded: 20520 of patient: UCSF-PDGM-0479
# Number of images loaded: 20580 of patient: UCSF-PDGM-0480
# Number of images loaded: 20640 of patient: UCSF-PDGM-0481
# Number of images loaded: 20700 of patient: UCSF-PDGM-0484
# Number of images loaded: 20760 of patient: UCSF-PDGM-0487
# Number of images loaded: 20820 of patient: UCSF-PDGM-0488
# Number of images loaded: 20880 of patient: UCSF-PDGM-0491
# Number of images loaded: 20940 of patient: UCSF-PDGM-0492
# Number of images loaded: 21000 of patient: UCSF-PDGM-0493
# Number of images loaded: 21060 of patient: UCSF-PDGM-0494
# Number of images loaded: 21120 of patient: UCSF-PDGM-0495
# Number of images loaded: 21180 of patient: UCSF-PDGM-0496
# Number of images loaded: 21240 of patient: UCSF-PDGM-0497
# Number of images loaded: 21300 of patient: UCSF-PDGM-0498
# Number of images loaded: 21360 of patient: UCSF-PDGM-0499
# Number of images loaded: 21420 of patient: UCSF-PDGM-0502
# Number of images loaded: 21480 of patient: UCSF-PDGM-0503
# Number of images loaded: 21540 of patient: UCSF-PDGM-0504
# Number of images loaded: 21600 of patient: UCSF-PDGM-0505
# Number of images loaded: 21660 of patient: UCSF-PDGM-0506
# Number of images loaded: 21720 of patient: UCSF-PDGM-0507
# Number of images loaded: 21780 of patient: UCSF-PDGM-0508
# Number of images loaded: 21840 of patient: UCSF-PDGM-0509
# Number of images loaded: 21900 of patient: UCSF-PDGM-0510
# Number of images loaded: 21960 of patient: UCSF-PDGM-0511
# Number of images loaded: 22020 of patient: UCSF-PDGM-0512
# Number of images loaded: 22080 of patient: UCSF-PDGM-0513
# Number of images loaded: 22140 of patient: UCSF-PDGM-0514
# Number of images loaded: 22200 of patient: UCSF-PDGM-0515
# Number of images loaded: 22260 of patient: UCSF-PDGM-0516
# Number of images loaded: 22320 of patient: UCSF-PDGM-0517
# Number of images loaded: 22380 of patient: UCSF-PDGM-0518
# Number of images loaded: 22440 of patient: UCSF-PDGM-0519

# %%
# Shape of the final input and output data
print(all_data_merged.shape)
print(all_data_tumour_mask.shape)

# %%
all_data_merged_m = np.max(all_data_merged)
all_data_merged_mi = np.min(all_data_merged)
print("Maximum pixel value in the input image of merged 3 modalities (T1Bias, T2Bias, ASL):", all_data_merged_m)
print("Minimum pixel value in the input image of merged 3 modalities (T1Bias, T2Bias, ASL):", all_data_merged_mi)

# Normalizing the input image data
print("After Normalization")
all_data_merged = (all_data_merged - all_data_merged_mi) / (all_data_merged_m - all_data_merged_mi)
print("Minimum pixel value in the input image of merged 3 modalities (T1Bias, T2Bias, ASL):", np.min(all_data_merged))
print("Maximum pixel value in the input image of merged 3 modalities (T1Bias, T2Bias, ASL):", np.max(all_data_merged))

# %%
all_data_tumour_mask_m = np.max(all_data_tumour_mask)
all_data_tumour_mask_mi = np.min(all_data_tumour_mask)
print("Maximum pixel value in the output image Tumour_segmentation:", all_data_tumour_mask_m)
print("Minimum pixel value in the output image Tumour_segmentation:", all_data_tumour_mask_mi)

#Normalizing the output image data (although not needed)
print("After normalization")
all_data_tumour_mask = (all_data_tumour_mask - all_data_tumour_mask_mi) / (all_data_tumour_mask_m - all_data_tumour_mask_mi)
print("Maximum pixel value in the output image Tumour_segmentation:", np.min(all_data_tumour_mask))
print("Minimum pixel value in the output image Tumour_segmentation:", np.max(all_data_tumour_mask))

# %%
# Create a frequency histogram of the normalized input image dataset

input_flattened_data = all_data_merged.flatten()

plt.hist(input_flattened_data, bins=50, color='blue', alpha=0.7)
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.title('Histogram of Pixel Intensities in all_data_merged array')
plt.show()

# %%
# Create a frequency histogram of the tumour masked output image dataset

output_flattened_data = all_data_tumour_mask.flatten()

plt.hist(output_flattened_data, bins=50, color='blue', alpha=0.7)
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.title('Histogram of Pixel Intensities in all_data_tumour_mask array')
plt.show()

# %%
# Count the occurrences of each value in the output_flattened_data
counter = Counter(output_flattened_data)

# Print the frequency count of value 0 and 1
print("Frequency of value 0:", counter[0])
print("Frequency of value 1:", counter[1])

# %%
X = all_data_merged.reshape(-1,240,240,1)
Y = all_data_tumour_mask.reshape(-1,240,240,1)

print("Collective shape of X dataset:", X.shape)
print("Collective shape of Y dataset:", Y.shape)

# First, splitting the data into training/testing and unseen data (e.g., 98% train/test, 2% unseen)
X_temp, X_unseen, Y_temp, Y_unseen = train_test_split(X, Y, test_size=0.02, random_state=22)

# Then, splitting the training/testing data into training and test sets (e.g., 70% train, 30% test)
X_train, X_test, Y_train, Y_test = train_test_split(X_temp, Y_temp, test_size=0.3, random_state=42)

# Now we have three datasets: training (X_train, Y_train), testing (X_test, Y_test), and unseen (X_unseen, Y_unseen)

print("X_unseen shape:", X_unseen.shape)
print("Y_unseen shape:", Y_unseen.shape)
print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)
print("X_test shape:", X_test.shape)
print("Y_test shape:", Y_test.shape)

# %%
# Sample training Input image and its corresponding output image
plt.figure(figsize=[10,10])

plt.subplot(121)
curr_img = np.reshape(X_train[1001], (240,240))
plt.title("Training Input Image")
plt.imshow(curr_img, cmap='gray')

plt.subplot(122)
curr_img = np.reshape(Y_train[1001], (240,240))
plt.title("Training Output Image")
plt.imshow(curr_img, cmap='gray')

# %%
# Sample test Input image and its corresponding output image

plt.figure(figsize=[10,10])

plt.subplot(121)
curr_img = np.reshape(X_test[850], (240,240))
plt.title("Test Input Image")
plt.imshow(curr_img, cmap='gray')

plt.subplot(122)
curr_img = np.reshape(Y_test[850], (240,240))
plt.title("Test Output Image")
plt.imshow(curr_img, cmap='gray')

# %%
def unet_model(input_size=(240, 240, 1)):
    inputs = Input(input_size)
    
    # Contracting path
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(inputs)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(p1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(p2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    # Bottleneck
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(p3)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(c4)

    # Expanding path
    u5 = UpSampling2D((2, 2))(c4)
    u5 = concatenate([u5, c3])
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(u5)
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(c5)

    u6 = UpSampling2D((2, 2))(c5)
    u6 = concatenate([u6, c2])
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(u6)
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(c6)

    u7 = UpSampling2D((2, 2))(c6)
    u7 = concatenate([u7, c1])
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(u7)
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(c7)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c7)

    model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
    return model

# %%
def dice_coef(y_true, y_pred):
    smooth = 1.
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)

model = unet_model()
model.compile(optimizer=tf.keras.optimizers.Adam(), loss= 'binary_crossentropy', metrics=[dice_coef])
model.summary()

# %%
plot_model(model)

# %%
t = time.process_time()
model_train = model.fit(X_train, Y_train, batch_size=16,epochs=100,verbose=1)
elapsed_time = time.process_time() - t
print("\nTotal time taken to train the model:", elapsed_time//60, "minutes")

# %%
tf.keras.backend.clear_session() # clearing any previous tensorflow sessions

# %%
# Defining a function for calculating IoU
def calculate_iou(y_true, y_pred):
    y_true = np.round(y_true).flatten()
    y_pred = np.round(y_pred).flatten()
    return jaccard_score(y_true, y_pred, zero_division=1)

# Defining a function for calculating PSNR
def calculate_psnr(y_true, y_pred):
    return psnr(y_true, y_pred, data_range=1.0)

# Defining a function for calculating the F2 score
def calculate_f2(y_true, y_pred):
    y_true = np.round(y_true).flatten()
    y_pred = np.round(y_pred).flatten()
    return fbeta_score(y_true, y_pred, beta=2, zero_division=1)

# Evaluating the model on the test data
loss, dice_score = model.evaluate(X_test, Y_test)
print("Loss:", loss)
print("Dice Score:", dice_score)

# Predicting on the test data
pred = model.predict(X_test)

# Initialize variables to store IoU, PSNR, and F2 scores of all the test data slices
iou_scores = []
psnr_scores = []
f2_scores = []

# Iterate through the test data and calculate IoU, PSNR, and F2 scores for each prediction
for i in range(len(X_test)):
    iou_scores.append(calculate_iou(Y_test[i], pred[i]))
    psnr_scores.append(calculate_psnr(Y_test[i], pred[i]))
    f2_scores.append(calculate_f2(Y_test[i], pred[i]))

# Print the average IoU, PSNR, and F2 scores
print("Average IoU:", np.mean(iou_scores))
print("Average PSNR:", np.mean(psnr_scores))
print("Average F2 Score:", np.mean(f2_scores))

# %%
# Choosing 5 random image slices to visualise from the test set
indices = [1000, 2400, 3600, 4550, 5000]
image_counter = 1

plt.figure(figsize=(15, 15))

for i, index in enumerate(indices):
    # Get the input image, true mask, and predicted mask
    input_image = X_test[index]
    true_mask = Y_test[index]
    predicted_mask = model.predict(input_image[np.newaxis, ...])[0]  # Adding a batch dimension for prediction
    
    # Display the input image
    plt.subplot(5, 3, 3*i+1)
    plt.imshow(input_image[..., 0], cmap='gray')
    plt.title(f'Input Image: {image_counter}')
    plt.axis('off')
    
    # Display the true mask
    plt.subplot(5, 3, 3*i+2)
    plt.imshow(true_mask[..., 0], cmap='gray')
    plt.title(f'True Mask: {image_counter}')
    plt.axis('off')
    
    # Display the predicted mask
    plt.subplot(5, 3, 3*i+3)
    plt.imshow(predicted_mask[..., 0], cmap='gray')
    plt.title(f'Predicted Mask: {image_counter} ')
    plt.axis('off')

    image_counter = image_counter+1

plt.show()

# %%
dice_scores = []

for i in range(len(X_unseen)):
    predicted_mask = model.predict(np.expand_dims(X_unseen[i], axis=0))
    predicted_mask = np.squeeze(predicted_mask)
    ground_truth_mask = Y_unseen[i].squeeze()

    # Dice Score
    dice_score = (2 * np.sum(predicted_mask * ground_truth_mask)) / (np.sum(predicted_mask) + np.sum(ground_truth_mask))
    dice_scores.append(dice_score)

df = pd.DataFrame({
    'DS T1BiasASLT2BiasFlairBias': dice_scores
})

df.to_csv('dataframeT1BiasASLT2BiasFlairBiasToTumourSeg.csv', index=False)

# Visualization of Dice Scores
plt.figure(figsize=(10, 5))
plt.hist(dice_scores, bins=20, color='b', alpha=0.7, rwidth=0.85)
plt.xlabel('Dice Score')
plt.ylabel('Count')
plt.title('Histogram of Dice Scores for Unseen Data')
plt.show()

# %%
df = pd.read_csv('dataframeT1BiasASLT2BiasFlairBiasToTumourSeg.csv')
df.tail(20)

# %%
plt.figure(figsize=(10, 10))

plt.subplot(2,2,1)
plt.imshow(X_unseen[250], cmap='gray')
plt.title('Input Image')

plt.subplot(2,2,2)
plt.imshow(Y_unseen[250], cmap='gray')
plt.title('Output Image')

plt.subplot(2,2,3)
plt.imshow(X_unseen[18], cmap='gray')
plt.title('Input Image')

plt.subplot(2,2,4)
plt.imshow(Y_unseen[18], cmap='gray')
plt.title('Output Image')

plt.show()

# %%
# Extract the Dice scores and slice numbers from the DataFrame
dice_scores = df['DS T1BiasASLT2BiasFlairBias'].values
slice_numbers = df.index.values

# Create a histogram of the Dice scores for each slice number
plt.figure(figsize=(10, 5))
plt.bar(slice_numbers, dice_scores, color='blue')
plt.xlabel('Slice Number')
plt.ylabel('Dice Score')
plt.title('Histogram of Dice Scores for Each Slice')
plt.grid(axis='y')
plt.show()
