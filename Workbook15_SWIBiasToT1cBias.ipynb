# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib  # for reading MR images
import tensorflow as tf
import keras as k
from tensorflow.keras import layers, regularizers
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
from keras.utils.vis_utils import plot_model
from collections import Counter
from sklearn.metrics import fbeta_score
from sklearn.metrics import jaccard_score
from skimage.metrics import peak_signal_noise_ratio as psnr
import pandas as pd
import seaborn as sns
tf.keras.backend.clear_session() # clearing any previous tensorflow sessions
# Out:
# 2023-09-01 14:33:09.515434: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-01 14:33:10.962319: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-09-01 14:33:17.209738: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.7/lib64:/opt/Python/Python-3.10.1/lib:/opt/ucl/lib:/usr/X11R6/lib
# 2023-09-01 14:33:17.210386: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.7/lib64:/opt/Python/Python-3.10.1/lib:/opt/ucl/lib:/usr/X11R6/lib
# 2023-09-01 14:33:17.210419: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
#Loading Dataset
t = time.process_time()

# Base directory path where the patient data is stored
base_directory_path = '/cluster/project2/UCSF_PDGM_dataset/UCSF-PDGM-v3/'

# Patient directories are named 'UCSF-PDGM-XXXX_nifti', where XXXX is the patient ID
all_patient_ids = [f"UCSF-PDGM-{str(i).zfill(4)}" for i in range(4, 542)]  # This will generate IDs from 0001 to 0541

# Excluded patients list because of FileNotFoundError, IndexError, ImageFileError
exclude_unavailbale_patients = {'UCSF-PDGM-0006', 'UCSF-PDGM-0028', 'UCSF-PDGM-0051', 'UCSF-PDGM-0052', 'UCSF-PDGM-0054', 'UCSF-PDGM-0060', 
                                'UCSF-PDGM-0062', 'UCSF-PDGM-0081', 'UCSF-PDGM-0098', 'UCSF-PDGM-0100', 'UCSF-PDGM-0108', 'UCSF-PDGM-0110',
                                'UCSF-PDGM-0117', 'UCSF-PDGM-0120', 'UCSF-PDGM-0125', 'UCSF-PDGM-0138', 'UCSF-PDGM-0171', 'UCSF-PDGM-0175',
                                'UCSF-PDGM-0177', 'UCSF-PDGM-0181', 'UCSF-PDGM-0192', 'UCSF-PDGM-0194', 'UCSF-PDGM-0199', 'UCSF-PDGM-0203',
                                'UCSF-PDGM-0206', 'UCSF-PDGM-0211', 'UCSF-PDGM-0216', 'UCSF-PDGM-0217', 'UCSF-PDGM-0218', 'UCSF-PDGM-0219',
                                'UCSF-PDGM-0220', 'UCSF-PDGM-0221', 'UCSF-PDGM-0222', 'UCSF-PDGM-0224', 'UCSF-PDGM-0226', 'UCSF-PDGM-0230',
                                'UCSF-PDGM-0231', 'UCSF-PDGM-0232', 'UCSF-PDGM-0233', 'UCSF-PDGM-0234', 'UCSF-PDGM-0235', 'UCSF-PDGM-0236',
                                'UCSF-PDGM-0237', 'UCSF-PDGM-0238', 'UCSF-PDGM-0239', 'UCSF-PDGM-0240', 'UCSF-PDGM-0241', 'UCSF-PDGM-0242',
                                'UCSF-PDGM-0244', 'UCSF-PDGM-0245', 'UCSF-PDGM-0246', 'UCSF-PDGM-0247', 'UCSF-PDGM-0248', 'UCSF-PDGM-0249',
                                'UCSF-PDGM-0250', 'UCSF-PDGM-0251', 'UCSF-PDGM-0252', 'UCSF-PDGM-0254', 'UCSF-PDGM-0255', 'UCSF-PDGM-0256',
                                'UCSF-PDGM-0257', 'UCSF-PDGM-0258', 'UCSF-PDGM-0259', 'UCSF-PDGM-0260', 'UCSF-PDGM-0261', 'UCSF-PDGM-0262',
                                'UCSF-PDGM-0263', 'UCSF-PDGM-0264', 'UCSF-PDGM-0265', 'UCSF-PDGM-0266', 'UCSF-PDGM-0267', 'UCSF-PDGM-0268',
                                'UCSF-PDGM-0269', 'UCSF-PDGM-0271', 'UCSF-PDGM-0272', 'UCSF-PDGM-0274', 'UCSF-PDGM-0277', 'UCSF-PDGM-0278',
                                'UCSF-PDGM-0281', 'UCSF-PDGM-0282', 'UCSF-PDGM-0286', 'UCSF-PDGM-0289', 'UCSF-PDGM-0292', 'UCSF-PDGM-0293',
                                'UCSF-PDGM-0294', 'UCSF-PDGM-0298', 'UCSF-PDGM-0299', 'UCSF-PDGM-0300', 'UCSF-PDGM-0301', 'UCSF-PDGM-0302',
                                'UCSF-PDGM-0305', 'UCSF-PDGM-0307', 'UCSF-PDGM-0308', 'UCSF-PDGM-0315', 'UCSF-PDGM-0322', 'UCSF-PDGM-0326',
                                'UCSF-PDGM-0327', 'UCSF-PDGM-0331', 'UCSF-PDGM-0345', 'UCSF-PDGM-0349', 'UCSF-PDGM-0351', 'UCSF-PDGM-0352',
                                'UCSF-PDGM-0357', 'UCSF-PDGM-0365', 'UCSF-PDGM-0371', 'UCSF-PDGM-0374', 'UCSF-PDGM-0378', 'UCSF-PDGM-0383',
                                'UCSF-PDGM-0388', 'UCSF-PDGM-0395', 'UCSF-PDGM-0408', 'UCSF-PDGM-0436', 'UCSF-PDGM-0437', 'UCSF-PDGM-0438',
                                'UCSF-PDGM-0439', 'UCSF-PDGM-0440', 'UCSF-PDGM-0441', 'UCSF-PDGM-0442', 'UCSF-PDGM-0444', 'UCSF-PDGM-0445', 
                                'UCSF-PDGM-0446', 'UCSF-PDGM-0448', 'UCSF-PDGM-0449', 'UCSF-PDGM-0456', 'UCSF-PDGM-0465', 'UCSF-PDGM-0466', 
                                'UCSF-PDGM-0468', 'UCSF-PDGM-0469', 'UCSF-PDGM-0473', 'UCSF-PDGM-0474', 'UCSF-PDGM-0475', 'UCSF-PDGM-0476', 
                                'UCSF-PDGM-0477', 'UCSF-PDGM-0478', 'UCSF-PDGM-0482', 'UCSF-PDGM-0483', 'UCSF-PDGM-0485', 'UCSF-PDGM-0486',
                                'UCSF-PDGM-0489', 'UCSF-PDGM-0490', 'UCSF-PDGM-0500', 'UCSF-PDGM-0501', 'UCSF-PDGM-0530', 'UCSF-PDGM-0534', 
                                'UCSF-PDGM-0535', 'UCSF-PDGM-0537', 'UCSF-PDGM-0540', 'UCSF-PDGM-0541'}

all_data_swi_bias = []
all_data_t1c_bias = []
num_of_images = 0
num_of_patients = 0

print("Loading images: ", end="")
for patient_id in all_patient_ids:

    if patient_id in exclude_unavailbale_patients:
        continue
    
    # Construct file paths for the current patient
    swi_bias_path = os.path.join(base_directory_path, f"{patient_id}_nifti", f"{patient_id}_SWI_bias.nii.gz")
    t1c_bias_path = os.path.join(base_directory_path, f"{patient_id}_nifti", f"{patient_id}_T1c_bias.nii.gz")
    
    # Load the images
    image_swi_bias = nib.load(swi_bias_path)
    image_t1c_bias = nib.load(t1c_bias_path)
    
    # Get the image data as numpy arrays
    data_swi_bias = image_swi_bias.get_fdata()
    data_t1c_bias = image_t1c_bias.get_fdata()

    slice_start = 70  # Starting slice number
    slice_end = 85    # End slice number
    
    # Append the data to the lists
    for i in range(slice_start, slice_end):
        all_data_swi_bias.append(data_swi_bias[:, :, i])
        all_data_t1c_bias.append(data_t1c_bias[:, :, i])
        num_of_images = num_of_images + 1
    num_of_patients = num_of_patients + 1
    print(".", end="")

print(" => Images Loaded.")
elapsed_time = time.process_time() - t
print("Total time taken to load",num_of_images, "images of", num_of_patients,"patients:",elapsed_time, "seconds or", elapsed_time//60, "minutes.")
print("Total number of slices considered:", slice_end-slice_start)
# Convert lists to numpy arrays for further processing if needed
all_data_swi_bias = np.asarray(all_data_swi_bias)
all_data_t1c_bias = np.asarray(all_data_t1c_bias)
# Out:
# Loading images: ...................................................................................................................................................................................................................................................................................................................................................................................................... => Images Loaded.
# Total time taken to load 5850 images of 390 patients: 184.200683113 seconds or 3.0 minutes.
# Total number of slices considered: 15

# %%
# Shape of the final input and output data
print(all_data_swi_bias.shape)
print(all_data_t1c_bias.shape)
# Out:
# (5850, 240, 240)
# (5850, 240, 240)

# %%
all_data_swi_bias_m = np.max(all_data_swi_bias)
all_data_swi_bias_mi = np.min(all_data_swi_bias)
print("Maximum pixel value in the input image SWI Bias:", all_data_swi_bias_m)
print("Minimum pixel value in the input image SWI Bias:", all_data_swi_bias_mi)

# Normalizing the input image data
print("After Normalization")
all_data_swi_bias = (all_data_swi_bias - all_data_swi_bias_mi) / (all_data_swi_bias_m - all_data_swi_bias_mi)
print("Minimum pixel value in the input image SWI Bias:", np.min(all_data_swi_bias))
print("Maximum pixel value in the input image SWI Bias:", np.max(all_data_swi_bias))
# Out:
# Maximum pixel value in the input image SWI Bias: 11255.25875762105
# Minimum pixel value in the input image SWI Bias: 0.0
# After Normalization
# Minimum pixel value in the input image SWI Bias: 0.0
# Maximum pixel value in the input image SWI Bias: 1.0

# %%
all_data_t1c_bias_m = np.max(all_data_t1c_bias)
all_data_t1c_bias_mi = np.min(all_data_t1c_bias)
print("Maximum pixel value in the output image T1c_bias:", all_data_t1c_bias_m)
print("Minimum pixel value in the output image T1c_bias:", all_data_t1c_bias_mi)

#Normalizing the output image data (although not needed)
print("After normalization")
all_data_t1c_bias = (all_data_t1c_bias - all_data_t1c_bias_mi) / (all_data_t1c_bias_m - all_data_t1c_bias_mi)
print("Minimum pixel value in the output image T1c_bias:", np.min(all_data_t1c_bias))
print("Maximum pixel value in the output image T1c_bias:", np.max(all_data_t1c_bias))
# Out:
# Maximum pixel value in the output image T1c_bias: 15849.36417222023
# Minimum pixel value in the output image T1c_bias: 0.0
# After normalization
# Minimum pixel value in the output image T1c_bias: 0.0
# Maximum pixel value in the output image T1c_bias: 1.0

# %%
# Create a frequency histogram of the normalized input image dataset
input_flattened_data = all_data_swi_bias.flatten()

plt.hist(input_flattened_data, bins=50, color='blue', alpha=0.7)
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.title('Histogram of Pixel Intensities in all_data_swi_bias array')
plt.show()

# %%
# Count the occurrences of each value in the input_flattened_data
counter = Counter(input_flattened_data)

# Print the frequency count of value 0 and 1
print("Frequency of value 0:", counter[0])
print("Frequency of value 1:", counter[1])
# Out:
# Frequency of value 0: 236538895
# Frequency of value 1: 1

# %%
# Create a frequency histogram of the tumour masked output image dataset
output_flattened_data = all_data_t1c_bias.flatten()

plt.hist(output_flattened_data, bins=50, color='blue', alpha=0.7)
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.title('Histogram of Pixel Intensities in all_data_t1c_bias array')
plt.show()

# %%
# Count the occurrences of each value in the output_flattened_data
counter = Counter(output_flattened_data)

# Print the frequency count of value 0 and 1
print("Frequency of value 0:", counter[0])
print("Frequency of value 1:", counter[1])
# Out:
# Frequency of value 0: 236540328
# Frequency of value 1: 1

# %%
X = all_data_swi_bias.reshape(-1,240,240,1)
Y = all_data_t1c_bias.reshape(-1,240,240,1)

print("Collective shape of X dataset:", X.shape)
print("Collective shape of Y dataset:", Y.shape)

# First, splitting the data into training/testing and unseen data (e.g., 98% train/test, 2% unseen)
X_temp, X_unseen, Y_temp, Y_unseen = train_test_split(X, Y, test_size=0.02, random_state=22)

# Then, splitting the training/testing data into training and test sets (e.g., 70% train, 30% test)
X_train, X_test, Y_train, Y_test = train_test_split(X_temp, Y_temp, test_size=0.3, random_state=42)

# Now we have three datasets: training (X_train, Y_train), testing (X_test, Y_test), and unseen (X_unseen, Y_unseen)

print("X_unseen shape:", X_unseen.shape)
print("Y_unseen shape:", Y_unseen.shape)
print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)
print("X_test shape:", X_test.shape)
print("Y_test shape:", Y_test.shape)
# Out:
# Collective shape of X dataset: (5850, 240, 240, 1)
# Collective shape of Y dataset: (5850, 240, 240, 1)
# X_unseen shape: (117, 240, 240, 1)
# Y_unseen shape: (117, 240, 240, 1)
# X_train shape: (4013, 240, 240, 1)
# Y_train shape: (4013, 240, 240, 1)
# X_test shape: (1720, 240, 240, 1)
# Y_test shape: (1720, 240, 240, 1)

# %%
# Sample training Input image and its corresponding output image
plt.figure(figsize=[10,10])

plt.subplot(121)
curr_img = np.reshape(X_train[2500], (240,240))
plt.title("Training Input Image")
plt.imshow(curr_img, cmap='gray')

plt.subplot(122)
curr_img = np.reshape(Y_train[2500], (240,240))
plt.title("Training Output Image")
plt.imshow(curr_img, cmap='gray')

# %%
# Sample test Input image and its corresponding output image

plt.figure(figsize=[10,10])

plt.subplot(121)
curr_img = np.reshape(X_test[650], (240,240))
plt.title("Test Input Image")
plt.imshow(curr_img, cmap='gray')

plt.subplot(122)
curr_img = np.reshape(Y_test[650], (240,240))
plt.title("Test Output Image")
plt.imshow(curr_img, cmap='gray')

# %%
def unet_model(input_size=(240, 240, 1)):
    inputs = Input(input_size)
    
    # Contracting path
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(inputs)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(p1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(p2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    # Bottleneck
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(p3)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(c4)

    # Expanding path
    u5 = UpSampling2D((2, 2))(c4)
    u5 = concatenate([u5, c3])
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(u5)
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(c5)

    u6 = UpSampling2D((2, 2))(c5)
    u6 = concatenate([u6, c2])
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(u6)
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(c6)

    u7 = UpSampling2D((2, 2))(c6)
    u7 = concatenate([u7, c1])
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(u7)
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal")(c7)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c7)

    model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
    return model

# %%
def dice_coef(y_true, y_pred):
    smooth = 1.
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)

model = unet_model()
model.compile(optimizer=tf.keras.optimizers.Adam(), loss= 'binary_crossentropy', metrics=[dice_coef])
model.summary()
# Out:
# 2023-09-01 14:47:02.375836: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-01 14:47:06.282214: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8167 MB memory:  -> device: 0, name: NVIDIA GeForce GTX TITAN X, pci bus id: 0000:02:00.0, compute capability: 5.2
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 240, 240, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 240, 240, 64  640         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 240, 240, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 120, 120, 64  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 120, 120, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 120, 120, 12  147584      ['conv2d_2[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 60, 60, 128)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 60, 60, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 60, 60, 256)  590080      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 30, 30, 256)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 30, 30, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 30, 30, 512)  2359808     ['conv2d_6[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 60, 60, 512)  0           ['conv2d_7[0][0]']
#
#  concatenate (Concatenate)      (None, 60, 60, 768)  0           ['up_sampling2d[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 60, 60, 256)  1769728     ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 60, 60, 256)  590080      ['conv2d_8[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 120, 120, 25  0          ['conv2d_9[0][0]']
#                                 6)
#
#  concatenate_1 (Concatenate)    (None, 120, 120, 38  0           ['up_sampling2d_1[0][0]',
#                                 4)                                'conv2d_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 120, 120, 12  442496      ['concatenate_1[0][0]']
#                                 8)
#
#  conv2d_11 (Conv2D)             (None, 120, 120, 12  147584      ['conv2d_10[0][0]']
#                                 8)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 240, 240, 12  0          ['conv2d_11[0][0]']
#                                 8)
#
#  concatenate_2 (Concatenate)    (None, 240, 240, 19  0           ['up_sampling2d_2[0][0]',
#                                 2)                                'conv2d_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 240, 240, 64  110656      ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 240, 240, 64  36928       ['conv2d_12[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 240, 240, 1)  65          ['conv2d_13[0][0]']
#
# ==================================================================================================
# Total params: 7,781,761
# Trainable params: 7,781,761
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model)

# %%
t = time.process_time()
model_train = model.fit(X_train, Y_train, batch_size=16,epochs=100,verbose=1)
elapsed_time = time.process_time() - t
print("\nTotal time taken to train the model:", elapsed_time//60, "minutes")
# Out:
# Epoch 1/100
# 2023-09-01 14:47:18.248519: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401
# 2023-09-01 14:47:23.285579: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.54GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-09-01 14:47:23.685837: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-09-01 14:47:23.752565: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.99GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-09-01 14:47:24.019218: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-09-01 14:47:24.019282: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.99GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-09-01 14:47:24.721522: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.22GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-09-01 14:47:24.939306: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.36GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-09-01 14:47:25.462258: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.26GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-09-01 14:47:25.731999: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.34GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 250/251 [============================>.] - ETA: 0s - loss: 0.1493 - dice_coef: 0.1525
# 2023-09-01 14:50:37.250022: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.47GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 251/251 [==============================] - 205s 774ms/step - loss: 0.1492 - dice_coef: 0.1525
# Epoch 2/100
# 251/251 [==============================] - 194s 774ms/step - loss: 0.1287 - dice_coef: 0.1581
# Epoch 3/100
# 251/251 [==============================] - 192s 766ms/step - loss: 0.1286 - dice_coef: 0.1586
# Epoch 4/100
# 251/251 [==============================] - 192s 766ms/step - loss: 0.1284 - dice_coef: 0.1592
# Epoch 5/100
# 251/251 [==============================] - 188s 749ms/step - loss: 0.1283 - dice_coef: 0.1595
# Epoch 6/100
# 251/251 [==============================] - 162s 646ms/step - loss: 0.1281 - dice_coef: 0.1599
# Epoch 7/100
# 251/251 [==============================] - 192s 765ms/step - loss: 0.1282 - dice_coef: 0.1600
# Epoch 8/100
# 251/251 [==============================] - 193s 768ms/step - loss: 0.1282 - dice_coef: 0.1600
# Epoch 9/100
# 251/251 [==============================] - 192s 764ms/step - loss: 0.1280 - dice_coef: 0.1605
# Epoch 10/100
# 251/251 [==============================] - 189s 752ms/step - loss: 0.1279 - dice_coef: 0.1609
# Epoch 11/100
# 251/251 [==============================] - 188s 750ms/step - loss: 0.1280 - dice_coef: 0.1609
# Epoch 12/100
# 251/251 [==============================] - 175s 697ms/step - loss: 0.1280 - dice_coef: 0.1610
# Epoch 13/100
# 251/251 [==============================] - 170s 678ms/step - loss: 0.1279 - dice_coef: 0.1617
# Epoch 14/100
# 251/251 [==============================] - 188s 749ms/step - loss: 0.1277 - dice_coef: 0.1620
# Epoch 15/100
# 251/251 [==============================] - 189s 752ms/step - loss: 0.1277 - dice_coef: 0.1624
# Epoch 16/100
# 251/251 [==============================] - 189s 751ms/step - loss: 0.1275 - dice_coef: 0.1631
# Epoch 17/100
# 251/251 [==============================] - 188s 748ms/step - loss: 0.1274 - dice_coef: 0.1637
# Epoch 18/100
# 251/251 [==============================] - 189s 753ms/step - loss: 0.1272 - dice_coef: 0.1645
# Epoch 19/100
# 251/251 [==============================] - 173s 689ms/step - loss: 0.1271 - dice_coef: 0.1650
# Epoch 20/100
# 251/251 [==============================] - 171s 683ms/step - loss: 0.1269 - dice_coef: 0.1662
# Epoch 21/100
# 251/251 [==============================] - 189s 752ms/step - loss: 0.1267 - dice_coef: 0.1673
# Epoch 22/100
# 251/251 [==============================] - 168s 671ms/step - loss: 0.1266 - dice_coef: 0.1680
# Epoch 23/100
# 251/251 [==============================] - 151s 601ms/step - loss: 0.1264 - dice_coef: 0.1691
# Epoch 24/100
# 251/251 [==============================] - 152s 605ms/step - loss: 0.1261 - dice_coef: 0.1703
# Epoch 25/100
# 251/251 [==============================] - 151s 602ms/step - loss: 0.1260 - dice_coef: 0.1707
# Epoch 26/100
# 251/251 [==============================] - 151s 603ms/step - loss: 0.1259 - dice_coef: 0.1715
# Epoch 27/100
# 251/251 [==============================] - 156s 623ms/step - loss: 0.1258 - dice_coef: 0.1720
# Epoch 28/100
# 251/251 [==============================] - 188s 748ms/step - loss: 0.1257 - dice_coef: 0.1726
# Epoch 29/100
# 251/251 [==============================] - 188s 748ms/step - loss: 0.1257 - dice_coef: 0.1727
# Epoch 30/100
# 251/251 [==============================] - 188s 749ms/step - loss: 0.1256 - dice_coef: 0.1731
# Epoch 31/100
# 251/251 [==============================] - 187s 746ms/step - loss: 0.1256 - dice_coef: 0.1733
# Epoch 32/100
# 251/251 [==============================] - 188s 750ms/step - loss: 0.1256 - dice_coef: 0.1733
# Epoch 33/100
# 251/251 [==============================] - 183s 730ms/step - loss: 0.1256 - dice_coef: 0.1736
# Epoch 34/100
# 251/251 [==============================] - 162s 644ms/step - loss: 0.1255 - dice_coef: 0.1738
# Epoch 35/100
# 251/251 [==============================] - 188s 748ms/step - loss: 0.1255 - dice_coef: 0.1738
# Epoch 36/100
# 251/251 [==============================] - 188s 747ms/step - loss: 0.1255 - dice_coef: 0.1737
# Epoch 37/100
# 251/251 [==============================] - 188s 748ms/step - loss: 0.1255 - dice_coef: 0.1743
# Epoch 38/100
# 251/251 [==============================] - 188s 749ms/step - loss: 0.1255 - dice_coef: 0.1740
# Epoch 39/100
# 251/251 [==============================] - 187s 745ms/step - loss: 0.1254 - dice_coef: 0.1744
# Epoch 40/100
# 251/251 [==============================] - 187s 745ms/step - loss: 0.1254 - dice_coef: 0.1746
# Epoch 41/100
# 251/251 [==============================] - 165s 657ms/step - loss: 0.1254 - dice_coef: 0.1745
# Epoch 42/100
# 251/251 [==============================] - 182s 725ms/step - loss: 0.1254 - dice_coef: 0.1747
# Epoch 43/100
# 251/251 [==============================] - 188s 748ms/step - loss: 0.1254 - dice_coef: 0.1746
# Epoch 44/100
# 251/251 [==============================] - 187s 744ms/step - loss: 0.1254 - dice_coef: 0.1746
# Epoch 45/100
# 251/251 [==============================] - 187s 747ms/step - loss: 0.1253 - dice_coef: 0.1750
# Epoch 46/100
# 251/251 [==============================] - 188s 747ms/step - loss: 0.1253 - dice_coef: 0.1751
# Epoch 47/100
# 251/251 [==============================] - 187s 747ms/step - loss: 0.1253 - dice_coef: 0.1752
# Epoch 48/100
# 251/251 [==============================] - 172s 685ms/step - loss: 0.1253 - dice_coef: 0.1751
# Epoch 49/100
# 251/251 [==============================] - 174s 694ms/step - loss: 0.1253 - dice_coef: 0.1753
# Epoch 50/100
# 251/251 [==============================] - 187s 747ms/step - loss: 0.1253 - dice_coef: 0.1753
# Epoch 51/100
# 251/251 [==============================] - 188s 747ms/step - loss: 0.1253 - dice_coef: 0.1753
# Epoch 52/100
# 251/251 [==============================] - 188s 749ms/step - loss: 0.1253 - dice_coef: 0.1752
# Epoch 53/100
# 251/251 [==============================] - 188s 748ms/step - loss: 0.1252 - dice_coef: 0.1754
# Epoch 54/100
# 251/251 [==============================] - 187s 747ms/step - loss: 0.1252 - dice_coef: 0.1755
# Epoch 55/100
# 251/251 [==============================] - 179s 712ms/step - loss: 0.1252 - dice_coef: 0.1756
# Epoch 56/100
# 251/251 [==============================] - 168s 668ms/step - loss: 0.1252 - dice_coef: 0.1755
# Epoch 57/100
# 251/251 [==============================] - 187s 744ms/step - loss: 0.1252 - dice_coef: 0.1755
# Epoch 58/100
# 251/251 [==============================] - 187s 746ms/step - loss: 0.1252 - dice_coef: 0.1757
# Epoch 59/100
# 251/251 [==============================] - 188s 748ms/step - loss: 0.1252 - dice_coef: 0.1757
# Epoch 60/100
# 251/251 [==============================] - 188s 748ms/step - loss: 0.1252 - dice_coef: 0.1757
# Epoch 61/100
# 251/251 [==============================] - 188s 748ms/step - loss: 0.1252 - dice_coef: 0.1758
# Epoch 62/100
# 251/251 [==============================] - 185s 739ms/step - loss: 0.1252 - dice_coef: 0.1756
# Epoch 63/100
# 251/251 [==============================] - 164s 652ms/step - loss: 0.1252 - dice_coef: 0.1756
# Epoch 64/100
# 251/251 [==============================] - 181s 720ms/step - loss: 0.1252 - dice_coef: 0.1759
# Epoch 65/100
# 251/251 [==============================] - 187s 745ms/step - loss: 0.1252 - dice_coef: 0.1758
# Epoch 66/100
# 251/251 [==============================] - 188s 751ms/step - loss: 0.1252 - dice_coef: 0.1759
# Epoch 67/100
# 251/251 [==============================] - 189s 751ms/step - loss: 0.1251 - dice_coef: 0.1760
# Epoch 68/100
# 251/251 [==============================] - 189s 751ms/step - loss: 0.1251 - dice_coef: 0.1761
# Epoch 69/100
# 251/251 [==============================] - 189s 753ms/step - loss: 0.1251 - dice_coef: 0.1761
# Epoch 70/100
# 251/251 [==============================] - 173s 687ms/step - loss: 0.1252 - dice_coef: 0.1759
# Epoch 71/100
# 251/251 [==============================] - 175s 698ms/step - loss: 0.1252 - dice_coef: 0.1757
# Epoch 72/100
# 251/251 [==============================] - 188s 749ms/step - loss: 0.1251 - dice_coef: 0.1762
# Epoch 73/100
# 251/251 [==============================] - 189s 751ms/step - loss: 0.1251 - dice_coef: 0.1764
# Epoch 74/100
# 251/251 [==============================] - 189s 751ms/step - loss: 0.1251 - dice_coef: 0.1761
# Epoch 75/100
# 251/251 [==============================] - 189s 751ms/step - loss: 0.1251 - dice_coef: 0.1764
# Epoch 76/100
# 251/251 [==============================] - 189s 752ms/step - loss: 0.1251 - dice_coef: 0.1762
# Epoch 77/100
# 251/251 [==============================] - 181s 719ms/step - loss: 0.1251 - dice_coef: 0.1762
# Epoch 78/100
# 251/251 [==============================] - 168s 670ms/step - loss: 0.1251 - dice_coef: 0.1762
# Epoch 79/100
# 251/251 [==============================] - 188s 748ms/step - loss: 0.1251 - dice_coef: 0.1762
# Epoch 80/100
# 251/251 [==============================] - 188s 750ms/step - loss: 0.1251 - dice_coef: 0.1763
# Epoch 81/100
# 251/251 [==============================] - 188s 749ms/step - loss: 0.1251 - dice_coef: 0.1764
# Epoch 82/100
# 251/251 [==============================] - 190s 757ms/step - loss: 0.1251 - dice_coef: 0.1764
# Epoch 83/100
# 251/251 [==============================] - 188s 750ms/step - loss: 0.1251 - dice_coef: 0.1765
# Epoch 84/100
# 251/251 [==============================] - 187s 745ms/step - loss: 0.1251 - dice_coef: 0.1764
# Epoch 85/100
# 251/251 [==============================] - 165s 657ms/step - loss: 0.1251 - dice_coef: 0.1764
# Epoch 86/100
# 251/251 [==============================] - 185s 738ms/step - loss: 0.1251 - dice_coef: 0.1764
# Epoch 87/100
# 251/251 [==============================] - 190s 755ms/step - loss: 0.1251 - dice_coef: 0.1763
# Epoch 88/100
# 251/251 [==============================] - 188s 748ms/step - loss: 0.1251 - dice_coef: 0.1764
# Epoch 89/100
# 251/251 [==============================] - 187s 744ms/step - loss: 0.1251 - dice_coef: 0.1765
# Epoch 90/100
# 251/251 [==============================] - 187s 747ms/step - loss: 0.1251 - dice_coef: 0.1766
# Epoch 91/100
# 251/251 [==============================] - 187s 745ms/step - loss: 0.1251 - dice_coef: 0.1763
# Epoch 92/100
# 251/251 [==============================] - 164s 654ms/step - loss: 0.1251 - dice_coef: 0.1765
# Epoch 93/100
# 251/251 [==============================] - 175s 699ms/step - loss: 0.1251 - dice_coef: 0.1766
# Epoch 94/100
# 251/251 [==============================] - 186s 742ms/step - loss: 0.1250 - dice_coef: 0.1766
# Epoch 95/100
# 251/251 [==============================] - 187s 744ms/step - loss: 0.1250 - dice_coef: 0.1765
# Epoch 96/100
# 251/251 [==============================] - 187s 745ms/step - loss: 0.1251 - dice_coef: 0.1766
# Epoch 97/100
# 251/251 [==============================] - 187s 745ms/step - loss: 0.1251 - dice_coef: 0.1765
# Epoch 98/100
# 251/251 [==============================] - 187s 746ms/step - loss: 0.1250 - dice_coef: 0.1766
# Epoch 99/100
# 251/251 [==============================] - 172s 683ms/step - loss: 0.1250 - dice_coef: 0.1767
# Epoch 100/100
# 251/251 [==============================] - 168s 670ms/step - loss: 0.1250 - dice_coef: 0.1766
#
# Total time taken to train the model: 228.0 minutes

# %%
# Defining a function for calculating IoU
def calculate_iou(y_true, y_pred):
    y_true = np.round(y_true).flatten()
    y_pred = np.round(y_pred).flatten()
    return jaccard_score(y_true, y_pred, zero_division=1)

# Defining a function for calculating PSNR
def calculate_psnr(y_true, y_pred):
    return psnr(y_true, y_pred, data_range=1.0)

# Defining a function for calculating the F2 score
def calculate_f2(y_true, y_pred):
    y_true = np.round(y_true).flatten()
    y_pred = np.round(y_pred).flatten()
    return fbeta_score(y_true, y_pred, beta=2, zero_division=1)

# Evaluating the model on the test data
loss, dice_score = model.evaluate(X_test, Y_test)
print("Loss:", loss)
print("Dice Score:", dice_score)

# Predicting on the test data
pred = model.predict(X_test)

# Initialize variables to store IoU, PSNR, and F2 scores of all the test data slices
iou_scores = []
psnr_scores = []
f2_scores = []

# Iterate through the test data and calculate IoU, PSNR, and F2 scores for each prediction
for i in range(len(X_test)):
    iou_scores.append(calculate_iou(Y_test[i], pred[i]))
    psnr_scores.append(calculate_psnr(Y_test[i], pred[i]))
    f2_scores.append(calculate_f2(Y_test[i], pred[i]))

# Print the average IoU, PSNR, and F2 scores
print("Average IoU:", np.mean(iou_scores))
print("Average PSNR:", np.mean(psnr_scores))
print("Average F2 Score:", np.mean(f2_scores))
# Out:
# 54/54 [==============================] - 31s 496ms/step - loss: 0.1266 - dice_coef: 0.1734
# Loss: 0.12660865485668182
# Dice Score: 0.17339734733104706
# 54/54 [==============================] - 24s 444ms/step
# Average IoU: 0.6005345219919073
# Average PSNR: 36.70397357136139
# Average F2 Score: 0.6689108737500633

# %%
# Choosing 5 random image slices to visualize from the test set
indices = [100, 200, 300, 400, 500]
image_counter = 1

plt.figure(figsize=(15, 15))

for i, index in enumerate(indices):
    # Get the input image, true mask, and predicted mask
    input_image = X_test[index]
    true_mask = Y_test[index]
    predicted_mask = model.predict(input_image[np.newaxis, ...])[0]  # Adding a batch dimension for prediction
    
    # Display the input image
    plt.subplot(5, 3, 3*i+1)
    plt.imshow(input_image[..., 0], cmap='gray')
    plt.title(f'Input Image: {image_counter}')
    plt.axis('off')
    
    # Display the true mask
    plt.subplot(5, 3, 3*i+2)
    plt.imshow(true_mask[..., 0], cmap='gray')
    plt.title(f'True Mask: {image_counter}')
    plt.axis('off')
    
    # Display the predicted mask
    plt.subplot(5, 3, 3*i+3)
    plt.imshow(predicted_mask[..., 0], cmap='gray')
    plt.title(f'Predicted Mask: {image_counter} ')
    plt.axis('off')

    image_counter = image_counter+1

plt.show()
# Out:
# 1/1 [==============================] - 1s 663ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step

# %%
dice_scores = []

for i in range(len(X_unseen)):
    predicted_mask = model.predict(np.expand_dims(X_unseen[i], axis=0))
    predicted_mask = np.squeeze(predicted_mask)
    ground_truth_mask = Y_unseen[i].squeeze()

    # Dice Score
    dice_score = (2 * np.sum(predicted_mask * ground_truth_mask)) / (np.sum(predicted_mask) + np.sum(ground_truth_mask))
    dice_scores.append(dice_score)

df = pd.DataFrame({
    'DS SWIBiasToT1cBias': dice_scores
})

df.to_csv('dataframeSWIBiasToT1cBias.csv', index=False)

# Visualization of Dice Scores
plt.figure(figsize=(10, 5))
plt.hist(dice_scores, bins=20, color='b', alpha=0.7, rwidth=0.85)
plt.xlabel('Dice Score')
plt.ylabel('Count')
plt.title('Histogram of Dice Scores for Unseen Data')
plt.show()
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 46ms/step

# %%
df = pd.read_csv('dataframeSWIBiasToT1cBias.csv')
df.head(20)
# Out:
#     DS SWIBiasToT1cBias
# 0              0.202279
# 1              0.189858
# 2              0.165234
# 3              0.245945
# 4              0.137841
# 5              0.176739
# 6              0.158051
# 7              0.168802
# 8              0.168558
# 9              0.190372
# 10             0.184614
# 11             0.130436
# 12             0.148632
# 13             0.124321
# 14             0.127667
# 15             0.105862
# 16             0.129590
# 17             0.231155
# 18             0.185471
# 19             0.148474

# %%
df.tail(10)
# Out:
#      DS SWIBiasToT1cBias
# 107             0.190250
# 108             0.161891
# 109             0.123756
# 110             0.016520
# 111             0.197258
# 112             0.122495
# 113             0.213748
# 114             0.186124
# 115             0.137455
# 116             0.153011

# %%
plt.figure(figsize=(10, 10))

plt.subplot(2,2,1)
plt.imshow(X_unseen[2], cmap='gray')
plt.title('Input Image')

plt.subplot(2,2,2)
plt.imshow(Y_unseen[2], cmap='gray')
plt.title('Output Image')

plt.subplot(2,2,3)
plt.imshow(X_unseen[4], cmap='gray')
plt.title('Input Image')

plt.subplot(2,2,4)
plt.imshow(Y_unseen[4], cmap='gray')
plt.title('Output Image')

plt.show()

# %%
# Extract the Dice scores and slice numbers from the DataFrame
dice_scores = df['DS SWIBiasToT1cBias'].values
slice_numbers = df.index.values

# Create a histogram of the Dice scores for each slice number
plt.figure(figsize=(10, 5))
plt.bar(slice_numbers, dice_scores, color='blue')
plt.xlabel('Slice Number')
plt.ylabel('Dice Score')
plt.title('Histogram of Dice Scores for Each Slice')
plt.grid(axis='y')
plt.show()
